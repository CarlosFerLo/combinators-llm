# %% [markdown]
# # Demo

# %%
from combinators_llm import CombinatorsLlm

llm = CombinatorsLlm()

# %%
print(llm("A -> B -> A"))
# Out:
#  S ( K ( K K ) ) K
# [' K ( S ( K K ) ) ( K K ) K ( K K ) K ( K K ) ( S K ) K ( K K ) ( K K ) ( K K ( S K ) ( S K K ) ) ( K K ( K K K ) ) ', ' K ( K ( S S ( K K ) ) ) K       K ( K ( S K ) ( K K ) ( K K ) ( S K ( S S K ) ) )  K ( K ( S K ( S K ) ) ) )']
