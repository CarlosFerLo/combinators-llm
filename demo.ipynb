# %%
from combinators_llm import CombinatorsLlm

llm = CombinatorsLlm()

# %%
llm("A -> B -> A")
llm(["A -> A", "B -> C"])
# Out:
# ['  ( K ( K ( K ( ( ( K K K K ) ( ( K ) ) ) ( K )  S ( K )   K )  S ) ) )   K )  ',
#  ' ( ( ( ( K ( K ( K K K ) ( ( K ) ( ( K K ) ( S ) ( K ) ( K K ) ) ) ( K K ) ) ) ) ) ) ) ']
